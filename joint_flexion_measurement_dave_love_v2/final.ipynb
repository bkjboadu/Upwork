# %% [markdown]
# #### IMPORT AND INSTALL DEPENDENCIES

# %%
import tensorflow as tf
import cv2,labelme
import shutil
from pathlib import Path
import os,uuid,time,json
import mediapipe as mp
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from filterpy.kalman import KalmanFilter
import matplotlib.pyplot as plt
import numpy as np,pandas as pd

from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from PyPDF2 import PdfMerger

import os,cvzone
from ultralytics import YOLO
from sort import *

# %% [markdown]
# #### ANALYTIC FUNCTIONS

# %%
mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic()
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles


def get_angles(results):
        mp_pose = mp.solutions.pose
        wrist = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]
        index = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_INDEX]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]

        # Convert landmarks to numpy arrays
        wrist = np.array([wrist.x, wrist.y, wrist.z])
        index = np.array([index.x, index.y, index.z])
        elbow = np.array([elbow.x, elbow.y, elbow.z])

        # Calculate the vectors
        v1 = index - wrist
        v2 = elbow - wrist

        # Calculate the angle using arccos
        wrist_angle = np.degrees(np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))))

        wrist_angle = wrist_angle.astype(int)


        # Calculate the right elbow angle
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
        wrist = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]
        shoulder = np.array([shoulder.x, shoulder.y])
        elbow = np.array([elbow.x, elbow.y])
        wrist = np.array([wrist.x, wrist.y])
        v1 = shoulder - elbow
        v2 = wrist - elbow
        elbow_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        elbow_angle = np.degrees(elbow_angle).astype(int)


        # Calculate the right shoulder angle
        hip = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
        shoulder = np.array([shoulder.x, shoulder.y,shoulder.z])
        hip = np.array([hip.x, hip.y,hip.z])
        elbow = np.array([elbow.x, elbow.y,elbow.z])

        v1 = elbow[:2] - shoulder[:2]
        v2 = hip[:2] - shoulder[:2]
        shoulder_angle = np.arccos(np.dot(v2, v1) / (np.linalg.norm(v2) * np.linalg.norm(v1)))
        shoulder_angle = np.degrees(shoulder_angle).astype(int)
        
        if elbow[0] < shoulder[0]:
            shoulder_angle = -shoulder_angle
        else:
            if abs(shoulder_angle) >= 60:
                v1 = elbow - shoulder
                v2 = hip - shoulder
                shoulder_angle = np.arccos(np.dot(v2, v1) / (np.linalg.norm(v2) * np.linalg.norm(v1)))
                shoulder_angle = np.degrees(shoulder_angle).astype(int)
            else:
                shoulder_angle = abs(shoulder_angle)

        # Calculate the hip angle
        hip = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]
        hip = np.array([hip.x, hip.y,hip.z])
        knee = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE]
        knee = np.array([knee.x, knee.y, knee.z])
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        shoulder = np.array([shoulder.x, shoulder.y,shoulder.z])
        v1 = shoulder - hip
        v2 = knee - hip
        hip_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        hip_angle = np.degrees(hip_angle).astype(int)

        # Calculate the right knee angle
        ankle = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE]
        ankle = np.array([ankle.x, ankle.y, ankle.z])
        v1 = hip - knee
        v2 = ankle - knee
        knee_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        knee_angle = np.degrees(knee_angle).astype(int)

        # Calculate the right ankle angle
        heel = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL]
        heel = np.array([heel.x, heel.y, heel.z])
        v1 = knee - ankle
        v2 = heel - ankle
        ankle_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        ankle_angle = np.degrees(ankle_angle).astype(int) 

        return [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]



def display_angle_table(frame,results,width,height):
    
    wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle = get_angles(results)

    cv2.rectangle(frame, (width - 600, height - 250), (width, height), (0, 0, 0), cv2.FILLED)
    cv2.line(frame,(width - 600, height - 250), (width - 600, height ), (255,255,255), 4)
    for i in [250,210,170,130,90,50]:
        cv2.line(frame, (width - 600, height - i), (width, height - i), (255,255,255), 4)
    cv2.putText(frame, f'wrist angle: {wrist_angle}', (width - 600, height - 220), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f'elbow angle: {elbow_angle}', (width - 600, height - 180), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'shoulder angle: {shoulder_angle}', (width - 600, height - 140), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'Hip angle: {hip_angle}', (width - 600, height - 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'knee angle: {knee_angle}', (width - 600, height - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f'ankle angle: {ankle_angle}', (width - 600, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)
    return [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]


def mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    results = model.process(image)
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return results

def draw_landmarks(image,results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(250, 0, 0), thickness=2, circle_radius=2),)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(250, 0, 250), thickness=2, circle_radius=2),)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121, 121, 255), thickness=2, circle_radius=2),)
    

def extract_keypoint(results):
    face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    pose = np.array([[res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose,face,lh,rh])

def extract_images(video_path,output_folder,frames_to_extract):
    '''
    extracts images from video
    
    Arguments: 
        video_path: this is the path to the video we are extracting image from
        output_file: this is the directory our extracted image will be saved to
        frame_interval_seconds: this is the seconds interval to save each image
    '''

    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    frame_on_save = 0

    Path(output_folder).mkdir(exist_ok=True)
    folder_name = Path(video_path).stem

    while cap.isOpened():
        ret,frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Save the frame if it's within the desired interval
        if  frame_count in frames_to_extract:

            final_npy_dir = Path(output_folder,folder_name,f"{frame_on_save}.npy")
            image_np = np.array(frame)
        
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                            for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            # for i in range(len(detections['detection_boxes'])):
            box = detections['detection_boxes'][0]
            ymin, xmin, ymax, xmax = box
            ymin, xmin, ymax, xmax = int(ymin * height), int(xmin * width), int(ymax * height), int(xmax * width)

            player_frame = image_np[ymin:ymax, xmin:xmax]
            output_path = Path(output_folder, f"{str(uuid.uuid1())}.jpg")
            print(output_path)
            cv2.imwrite(str(output_path), player_frame)
    cap.release()

def view_fn(path,starting_point):
    cap = cv2.VideoCapture(path)
    frame_count = 0
    frame_to_save = 0
    folder_name = Path(path).stem
    with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            ret,frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            image_np = np.array(frame)
            
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                            for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            # for i in range(len(detections['detection_boxes'])):
            box = detections['detection_boxes'][0]
            ymin, xmin, ymax, xmax = box
            ymin, xmin, ymax, xmax = int(ymin * height), int(xmin * width), int(ymax * height), int(xmax * width)

            player_frame = image_np[ymin:ymax, xmin:xmax]
            
            margin = 50

            text_x = max(min(xmin - margin, player_frame.shape[0] - 150), 0)
            text_y = max(min(ymin - margin, player_frame.shape[1] - 150), 0)

            
            if text_x < player_frame.shape[1] and text_y < player_frame.shape[0]:
                cv2.putText(player_frame, f'{frame_count}', (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
            else:
                print("Text coordinates exceed frame dimensions.")
            cv2.imshow('frame',player_frame)
            

            if frame_count in np.arange(starting_point,starting_point + 25):
                image,results = mediapipe_detection(player_frame,holistic)
                extracted_results = extract_keypoint(results)
                final_npy_dir = Path('shot_detection_images','0',folder_name,f"{frame_to_save}.npy")
                Path('shot_detection_images','0',folder_name).mkdir(exist_ok=True)
                np.save(final_npy_dir,extracted_results)
                draw_landmarks(image,results)
                mp_drawing.draw_landmarks(player_frame, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                        mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 0, 0), thickness=2, circle_radius=2),)
                frame_to_save += 1
            elif frame_count > starting_point + 25:
                break

        cap.release()
        cv2.destroyAllWindows()

def create_dataframe(keypoints,name_to_save):
    df = pd.DataFrame(keypoints,columns=['wrist_angle','elbow_angle','shoulder_angle','hip_angle','knee_angle','ankle_angle'])
    df.index = range(1, len(df) + 1)
    df.to_excel(f"{name_to_save}.xlsx")

def kalman_filter(y):
    y = np.array(y)
        # Initialize Kalman filter parameters
    kf = KalmanFilter(dim_x=1, dim_z=1)
    kf.F = np.array([[1]])
    kf.H = np.array([[1]])
    # Process noise covariance
    kf.Q = np.array([[1e-3]])
    # Measurement noise covariance
    kf.R = np.array([[1e-1]])
    # Initial state
    kf.x = np.array([y[0]])

    # Initial state covariance
    kf.P *= 1e-2
    # Apply the Kalman filter to smooth the noisy data
    smoothed_values = []
    for measurement in y:
        kf.predict()
        kf.update(measurement)
        smoothed_values.append(kf.x[0])
    return smoothed_values


def plot_angle_graph_and_save(frames,angles,save_as,release_frame):
    x = np.array(frames)
    y = np.array(angles)

    def normalize_to_range(arrays, target_range=(-10, 30)):
        # Find the min and max values across all arrays
        min_val = np.min(arrays)
        max_val = np.max(arrays)

        # Calculate the scaling factor
        scale_factor = (target_range[1] - target_range[0]) / (max_val - min_val)

        # Normalize each array
        normalized_arrays = [(array - min_val) * scale_factor + target_range[0] for array in arrays]

        return normalized_arrays

    x = x[:len(y)]
    labels = ["wrist_angle", "elbow_angle", "shoulder_angle", "hip_angle", "knee_angle", "ankle_angle"]
    labels_to_normalize = ["elbow_angle","hip_angle", "knee_angle", "ankle_angle"]
    normalization_threshold = { "hip_angle":(-30,0), "knee_angle":(0,-45), "ankle_angle":(-20,40)}
    df = pd.DataFrame(y,index=x,columns=labels)
    # df.to_excel(f'final_{str(x[0])}.xlsx')
    


    labels_to_plot = ["elbow_angle", "shoulder_angle", "wrist_angle","hip_angle", "knee_angle", "ankle_angle"]

    for col in labels_to_plot:
        y = df.loc[:,col]
        

        if col in labels_to_plot[3:]:
            y = normalize_to_range(y)

        if col != 'wrist_angle':
            y_smooth = kalman_filter(y)
        else:
            y = [-value for value in y]
            y_smooth = kalman_filter(y)
            
        if col in labels_to_plot[3:]:
            plt.plot(x, y_smooth, label=col,linewidth=0.4)
        else:
            plt.plot(x, y_smooth, label=col)

    plt.axvline(x=release_frame, color='red', linestyle='--', label='Released')
    plt.title("Joint Flexion graph")
    plt.xlabel("frames")
    plt.ylabel("angles")
    plt.legend(loc="upper left", prop={'size':5})

    # Save the plot
    plt.savefig(save_as)
    plt.close()


def resize_image(img):
    target_width = 100
    height, width, _ = img.shape
    aspect_ratio = height / width
    target_height = int(target_width * aspect_ratio)
    resized_img = cv2.resize(img, (target_width, target_height))

    return resized_img


def create_pdf(pdf_filename, image_paths, folder_name,angles):
    c = canvas.Canvas(pdf_filename, pagesize=letter)

    # Add a header with the folder name
    c.setFont("Helvetica", 12)
    c.drawString(100, 750, f'Shot: #{folder_name}')


    # Draw the first image on the left side
    c.drawImage(image_paths[0], 100, 500, width=80, height=100)

    # Draw the second image on the right side
    c.drawImage(image_paths[1], 200, 500, width=300, height=200)
    c.showPage()
    c.save()

def create_combined_pdf(main_folder, pdf_filename,angles):
    merger = PdfMerger()
    print(angles)
    # Iterate through subfolders
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if the item in the main folder is a subfolder
        if os.path.isdir(subfolder_path):

            # List image files in the subfolder
            image_files = [file for file in os.listdir(subfolder_path) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Check if there are exactly 2 image files
            i = 0
            if len(image_files) == 2:
                image_paths = [os.path.join(subfolder_path, file) for file in image_files]
                
                # sheet_filename = f'{subfolder}.pdf'
                sheet_filename = os.path.join(subfolder_path,f'{subfolder}.pdf')

                # Create a PDF for each subfolder
                create_pdf(sheet_filename, image_paths, subfolder,angles[i])
                print(f'PDF created for {subfolder}')

                # Append the sheet to the main PDF
                merger.append(sheet_filename)
                i += 1
            else:
                print(f'Subfolder {subfolder} does not contain 2 images.')

    # Save the final PDF
    merger.write(pdf_filename)
    merger.close()

    # Remove individual subfolder PDFs
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            pdf_path = os.path.join(main_folder,subfolder_path, f'{subfolder}.pdf')
            print(pdf_path)
            if os.path.exists(pdf_path):
                os.remove(pdf_path)

    print('PDF creation complete.')


def get_shot_pose_image(frame_num, player_angles, player_frame):
    assert len(frame_num) == len(player_angles) == len(player_frame)
    cols = ['wrist_angle', 'elbow_angle', 'shoulder_angle', 'hip_angle', 'knee_angle', 'ankle_angle']
    df = pd.DataFrame(player_angles, index=np.arange(len(frame_num)).tolist(), columns=cols)

    # Get the indices of the first 5 maximum values of shoulder_angle
    shoulder_max_indices = df['shoulder_angle'].nlargest(10).index.tolist()

    # Choose the first 3 maximum values of elbow_angle within the shoulder_max_indices
    # wrist_max_indices = df.loc[shoulder_max_indices]['wrist_angle'].nsmallest(3).index.tolist()
    elbow_max_indices = df.loc[shoulder_max_indices]['elbow_angle'].nsmallest(7).index.tolist()

    # Choose the index with the lowest value of wrist_angle within the elbow_max_indices
    final_index = df.loc[elbow_max_indices]['wrist_angle'].idxmin()
    # final_index = df.loc[wrist_max_indices]['elbow_angle'].idxmin()

    return final_index

def get_contact_prediction_and_index(images):
    results = []
    model = load_model('contact_detection.h5')

    def preprocess(img):
        handball_frame = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        handball_contact = tf.image.resize(handball_frame,(120,120))
        normalized_contact = handball_contact / 255.0
        handball_contact = np.expand_dims(normalized_contact,axis=0)
        prediction = model.predict(handball_contact)
        return prediction[0]
        
    for image in images:
        results.append(preprocess(image))
    
    index = np.argmax(results)
    return index
        

coco_classes = [
    "Person", "Bicycle", "Car", "Motorcycle", "Airplane", "Bus", "Train", "Truck", "Boat", "Traffic light",
    "Fire hydrant", "Stop sign", "Parking meter", "Bench", "Bird", "Cat", "Dog", "Horse", "Sheep", "Cow",
    "Elephant", "Bear", "Zebra", "Giraffe", "Backpack", "Umbrella", "Handbag", "Tie", "Suitcase", "Frisbee",
    "Skis", "Snowboard", "Sports ball", "Kite", "Baseball bat", "Baseball glove", "Skateboard", "Surfboard",
    "Tennis racket", "Bottle", "Wine glass", "Cup", "Fork", "Knife", "Spoon", "Bowl", "Banana", "Apple",
    "Sandwich", "Orange", "Broccoli", "Carrot", "Hot dog", "Pizza", "Donut", "Cake", "Chair", "Couch",
    "Potted plant", "Bed", "Dining table", "Toilet", "TV", "Laptop", "Mouse", "Remote", "Keyboard",
    "Cell phone", "Microwave", "Oven", "Toaster", "Sink", "Refrigerator", "Book", "Clock", "Vase",
    "Scissors", "Teddy bear", "Hair drier", "Toothbrush"
]

# %% [markdown]
# #### FUNCTIONS FOR INFERENCE

# %%
def init_video_capture_and_writer(path):
    ''' initialize video capture and writer'''
    cap = cv2.VideoCapture(path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    output_video_path = 'output_vid/' + str(Path(path).stem) + '.avi'
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    output_video_writer = cv2.VideoWriter(output_video_path,fourcc,fps,(width,height))
    return cap, fps, output_video_writer, width, height

def process_frame(frame,model_yolo,labels):
    detections = np.empty((0,5))
    results = model_yolo(frame)
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1,y1,x2,y2 = np.array(box.xyxy[0]).astype(int)
            conf = box.conf[0]
            cls = labels[int(box.cls[0])]
            if cls == 'Person' and conf>0.3:
                currentArray = [x1,y1,x2,y2,conf]
                detections = np.vstack((detections,currentArray))
    return detections

def analyze_pose_and_predict(sequence,y_predict, actions):
    global shot_buffer,waiting_buffer,shot_frame_count,WAITING_BUFFER_SIZE
    y_predict = np.argmax(y_predict)
    shot_label = actions[y_predict]
    shot_buffer.append(shot_label)
    waiting_buffer.append(shot_label)

    if len(shot_buffer) > BUFFER_SIZE:
        shot_buffer.pop(0)

    if len(waiting_buffer) > WAITING_BUFFER_SIZE:
        waiting_buffer.pop(0)

    if shot_buffer.count('shot') >= THRESHOLD:
        shot_frame_count += 1
    
    


def handle_shot_detection(shot_frame_count_max,WAITING_BUFFER_SIZE,shot_buffer,BUFFER_SIZE,shot_frame_count, waiting_buffer, player_image_frame, at_shot_frame_num, at_shot_frame_angles, shot_num, path):
    global angles_to_pdf
    
    if shot_frame_count >= shot_frame_count_max:
        if waiting_buffer[-WAITING_BUFFER_SIZE:].count('noshot') == round(0.7*WAITING_BUFFER_SIZE):
            shot_num += 1
            max_contact_index = get_contact_prediction_and_index(player_image_frame)
            
            frames_to_plot = at_shot_frame_num[max_contact_index-70:max_contact_index+130]
            angles_to_plot = at_shot_frame_angles[max_contact_index-70:max_contact_index+130]
            angles_for_pdf.append(at_shot_frame_angles[max_contact_index])

            Path('report').mkdir(exist_ok=True)
            at_shot_dir = Path('report') / Path(path).stem / f"{shot_num}"
            at_shot_dir.mkdir(parents=True,exist_ok=True)
            img_path = at_shot_dir / f"{shot_num}.jpg"
            graph_path = at_shot_dir / f"graph_{shot_num}.png"
            shot_frame_count = 0

            plot_angle_graph_and_save(frames_to_plot,angles_to_plot,str(graph_path),release_frame=at_shot_frame_num[max_contact_index])
            cv2.imwrite(str(img_path),player_image_frame[max_contact_index])
            at_shot_frame_num = []
            at_shot_frame_angles = []
            player_image_frame = []
            shot_frame_count = 0
        else:
            if shot_buffer[-BUFFER_SIZE:].count('noshot') == BUFFER_SIZE:
                shot_frame_count = 0
    
    return shot_num, at_shot_frame_num, at_shot_frame_angles, player_image_frame, shot_frame_count

# %%
yolo_model = YOLO('yolov8l.pt')

# %%
def do_analysis(path):    
    player_image_frame = []
    player_image_keypoint = []
    at_shot_frame_num = []
    at_shot_frame_angles = []
    actions = {0:'noshot',1:'shot'}

    tracker = Sort(max_age=20,min_hits=3,iou_threshold=0.3)
    first_frame = True
    frame_count = 0
    cap, fps, output_video_writer, width, height= init_video_capture_and_writer(path)

    BUFFER_SIZE = 20 if fps < 70 else 30  # Adjust as needed
    WAITING_BUFFER_SIZE = BUFFER_SIZE + 20

    THRESHOLD = 10 if fps < 70 else 25 # Adjust as needed
    shot_frame_count_max = 12 if fps < 70 else 8
    shot_buffer = []
    waiting_buffer = []
    shot_frame_count= 0
    sequences = []
    mp_pose = mp.solutions.pose
    shot_num = 0
    angles_for_pdf = []
    total_count = []
    labels = ['Person']

    shot_model = load_model('shot_detection_lstm.h5')
    with mp_pose.Pose() as pose:
        while cap.isOpened():
            ret,frame = cap.read()
            if not ret:
                break

            if cv2.waitKey(1) & 0xFF == ord('q'):
               print('done')
               break

            if not ret:
               break

            frame_count += 1
            at_shot_frame_num.append(frame_count)
            
            cv2.putText(frame, f'Frame: {frame_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f'FPS: {fps:.2f}', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f'Shot number: {shot_num}', (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            # cv2.putText(image_np, f'Shot frame count: {shot_frame_count}', (10, 130), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)


            detections = process_frame(frame,yolo_model,coco_classes)
            
            track_results = tracker.update(detections)
            for result in track_results:
                x1,y1,x2,y2,id = np.array(result).astype(int)
                if first_frame:
                    w,h = x2-x1,y2-y1

                    cv2.rectangle(frame, (max(0,x1-70), max(0,y1-70)), (max(0,x2+70), max(0,y2+70)), (0,255,0), 2)
                    cvzone.putTextRect(frame,str(id),(max(0,x1-70),max(20,y1-70)),scale=1,thickness=2,offset=5)
                elif id == object_id_to_track:
                    w,h = x2-x1,y2-y1

                    cv2.rectangle(frame, (max(0,x1-70), max(0,y1-70)), (max(0,x2+70), max(0,y2+70)), (0,255,0), 2)
                    cvzone.putTextRect(frame,str(id),(max(0,x1-70),max(20,y1-70)),scale=1,thickness=2,offset=5)     

                    if w>0 and h>0:
                        player_frame = frame[max(0,y1-70):max(0,y2+70), max(0,x1-70):max(0,x2+70)]

                    if player_frame.size != 0:
                            player_frame_to_save = player_frame.copy()
                            player_image_frame.append(player_frame_to_save)
                            results = mediapipe_detection(player_frame,holistic)
                            keypoints = extract_keypoint(results)
                            player_image_keypoint.append(keypoints)

                    draw_landmarks(player_frame,results)
                    if results.pose_landmarks:
                        wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle = display_angle_table(frame,results,width,height)
                        item_list = [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]
                        at_shot_frame_angles.append(item_list)
                    else:
                        item_list = [0,0,0,0,0,0]
                        at_shot_frame_angles.append(item_list)
                    
                    sequences.append(keypoints)
                    sequence = sequences[-5:]
                    if len(sequence) == 5:
                        y_predict = shot_model.predict(np.expand_dims(sequence,axis=0))
                        y_predict = np.argmax(y_predict)
                        shot_label = actions[y_predict]
                        shot_buffer.append(shot_label)
                        waiting_buffer.append(shot_label)

                        if len(shot_buffer) > BUFFER_SIZE:
                           shot_buffer.pop(0)

                        if len(waiting_buffer) > WAITING_BUFFER_SIZE:
                           waiting_buffer.pop(0)

                        if shot_buffer.count('shot') >= THRESHOLD:
                           shot_frame_count += 1

                        if shot_frame_count >= shot_frame_count_max:
                           if waiting_buffer[-WAITING_BUFFER_SIZE:].count('noshot') == round(0.7*WAITING_BUFFER_SIZE):
                              shot_num += 1
                              max_contact_index = get_contact_prediction_and_index(player_image_frame)
                              
                              frames_to_plot = at_shot_frame_num[max_contact_index-70:max_contact_index+130]
                              angles_to_plot = at_shot_frame_angles[max_contact_index-70:max_contact_index+130]
                              angles_for_pdf.append(at_shot_frame_angles[max_contact_index])

                              Path('report').mkdir(exist_ok=True)
                              at_shot_dir = Path('report') / Path(path).stem / f"{shot_num}"
                              at_shot_dir.mkdir(parents=True,exist_ok=True)
                              img_path = at_shot_dir / f"{shot_num}.jpg"
                              graph_path = at_shot_dir / f"graph_{shot_num}.png"
                              shot_frame_count = 0

                              plot_angle_graph_and_save(frames_to_plot,angles_to_plot,str(graph_path),release_frame=at_shot_frame_num[max_contact_index])
                              cv2.imwrite(str(img_path),player_image_frame[max_contact_index])
                              at_shot_frame_num = []
                              at_shot_frame_angles = []
                              player_image_frame = []
                              shot_frame_count = 0
                        else:
                           if shot_buffer[-BUFFER_SIZE:].count('noshot') == BUFFER_SIZE:
                              shot_frame_count = 0
                    
            if first_frame:
                cv2.imshow('frame', cv2.resize(frame, (1200, 600)))
                cv2.waitKey(0)
                object_id_to_track = int(input('Enter the object id you want to track'))
                first_frame = False
            else:
                cv2.imshow('frame', cv2.resize(frame, (1200, 600)))
                output_video_writer.write(frame)

        
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    cap.release()
    cv2.destroyAllWindows()
    output_video_writer.release()
            
    pdf_init_path = os.path.join('report',f"{str(Path(path).stem)}")
    Path(pdf_init_path).mkdir(parents=True,exist_ok=True)
    create_combined_pdf(pdf_init_path, os.path.join(pdf_init_path,f"{str(Path(path).stem)}_shot_report.pdf"),angles_for_pdf)


do_analysis('videos/CharlieBrownDelaware5Shots.mov')
# Out:
# 0: 384x640 3 persons, 1 sports ball, 2486.0ms
# Speed: 71.0ms preprocess, 2486.0ms inference, 48.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 1361.0ms
# Speed: 9.0ms preprocess, 1361.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 1 baseball glove, 1418.0ms
# Speed: 7.0ms preprocess, 1418.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1336.0ms
# Speed: 5.0ms preprocess, 1336.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 sports balls, 1400.0ms
# Speed: 4.0ms preprocess, 1400.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 2501.0ms
# Speed: 9.0ms preprocess, 2501.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 2s 2s/step
#
# 0: 384x640 4 persons, 2 sports balls, 1843.0ms
# Speed: 5.0ms preprocess, 1843.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1711.0ms
# Speed: 4.0ms preprocess, 1711.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1538.0ms
# Speed: 8.0ms preprocess, 1538.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1470.0ms
# Speed: 6.0ms preprocess, 1470.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1185.0ms
# Speed: 3.0ms preprocess, 1185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1322.0ms
# Speed: 6.0ms preprocess, 1322.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1112.0ms
# Speed: 4.0ms preprocess, 1112.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1137.0ms
# Speed: 5.0ms preprocess, 1137.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1224.0ms
# Speed: 3.0ms preprocess, 1224.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1310.0ms
# Speed: 4.0ms preprocess, 1310.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1192.0ms
# Speed: 4.0ms preprocess, 1192.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1184.0ms
# Speed: 6.0ms preprocess, 1184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1142.0ms
# Speed: 4.0ms preprocess, 1142.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1156.0ms
# Speed: 5.0ms preprocess, 1156.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1185.0ms
# Speed: 3.0ms preprocess, 1185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1159.0ms
# Speed: 6.0ms preprocess, 1159.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1182.0ms
# Speed: 4.0ms preprocess, 1182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1195.0ms
# Speed: 7.0ms preprocess, 1195.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 30ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1177.0ms
# Speed: 6.0ms preprocess, 1177.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1386.0ms
# Speed: 4.0ms preprocess, 1386.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1333.0ms
# Speed: 6.0ms preprocess, 1333.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1310.0ms
# Speed: 5.0ms preprocess, 1310.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1227.0ms
# Speed: 3.0ms preprocess, 1227.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1185.0ms
# Speed: 4.0ms preprocess, 1185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1188.0ms
# Speed: 4.0ms preprocess, 1188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1193.0ms
# Speed: 6.0ms preprocess, 1193.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1174.0ms
# Speed: 4.0ms preprocess, 1174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1193.0ms
# Speed: 4.0ms preprocess, 1193.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1164.0ms
# Speed: 4.0ms preprocess, 1164.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1143.0ms
# Speed: 4.0ms preprocess, 1143.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1268.0ms
# Speed: 5.0ms preprocess, 1268.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1182.0ms
# Speed: 4.0ms preprocess, 1182.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1187.0ms
# Speed: 4.0ms preprocess, 1187.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1184.0ms
# Speed: 5.0ms preprocess, 1184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1172.0ms
# Speed: 6.0ms preprocess, 1172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1330.0ms
# Speed: 7.0ms preprocess, 1330.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1209.0ms
# Speed: 4.0ms preprocess, 1209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1172.0ms
# Speed: 6.0ms preprocess, 1172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1176.0ms
# Speed: 4.0ms preprocess, 1176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1204.0ms
# Speed: 3.0ms preprocess, 1204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1188.0ms
# Speed: 3.0ms preprocess, 1188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1185.0ms
# Speed: 3.0ms preprocess, 1185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1 clock, 1180.0ms
# Speed: 6.0ms preprocess, 1180.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 3 persons, 1 clock, 1170.0ms
# Speed: 3.0ms preprocess, 1170.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 1 clock, 1188.0ms
# Speed: 4.0ms preprocess, 1188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 3 persons, 1 clock, 1197.0ms
# Speed: 8.0ms preprocess, 1197.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 1 clock, 1163.0ms
# Speed: 4.0ms preprocess, 1163.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1167.0ms
# Speed: 6.0ms preprocess, 1167.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1282.0ms
# Speed: 8.0ms preprocess, 1282.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1180.0ms
# Speed: 4.0ms preprocess, 1180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1172.0ms
# Speed: 6.0ms preprocess, 1172.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1161.0ms
# Speed: 4.0ms preprocess, 1161.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1191.0ms
# Speed: 4.0ms preprocess, 1191.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 1 tennis racket, 1 clock, 1229.0ms
# Speed: 4.0ms preprocess, 1229.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 tennis racket, 1 clock, 1187.0ms
# Speed: 4.0ms preprocess, 1187.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1186.0ms
# Speed: 6.0ms preprocess, 1186.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1052.2ms
# Speed: 3.0ms preprocess, 1052.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1175.0ms
# Speed: 4.0ms preprocess, 1175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1183.0ms
# Speed: 4.0ms preprocess, 1183.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1178.0ms
# Speed: 4.0ms preprocess, 1178.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1171.0ms
# Speed: 5.0ms preprocess, 1171.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1184.0ms
# Speed: 4.0ms preprocess, 1184.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1195.0ms
# Speed: 6.0ms preprocess, 1195.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1173.0ms
# Speed: 3.0ms preprocess, 1173.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1129.0ms
# Speed: 3.0ms preprocess, 1129.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 5 persons, 1179.0ms
# Speed: 3.0ms preprocess, 1179.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1206.0ms
# Speed: 4.0ms preprocess, 1206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1180.0ms
# Speed: 4.0ms preprocess, 1180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1183.0ms
# Speed: 6.0ms preprocess, 1183.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1147.0ms
# Speed: 6.0ms preprocess, 1147.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1130.0ms
# Speed: 7.0ms preprocess, 1130.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1187.0ms
# Speed: 4.0ms preprocess, 1187.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1181.0ms
# Speed: 4.0ms preprocess, 1181.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1186.0ms
# Speed: 4.0ms preprocess, 1186.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1198.0ms
# Speed: 4.0ms preprocess, 1198.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1195.0ms
# Speed: 4.0ms preprocess, 1195.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1247.0ms
# Speed: 4.0ms preprocess, 1247.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1313.0ms
# Speed: 5.0ms preprocess, 1313.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1225.0ms
# Speed: 4.0ms preprocess, 1225.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 3573.7ms
# Speed: 6.0ms preprocess, 3573.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 2632.2ms
# Speed: 11.0ms preprocess, 2632.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1712.6ms
# Speed: 5.9ms preprocess, 1712.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3065.3ms
# Speed: 37.7ms preprocess, 3065.3ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1925.1ms
# Speed: 5.0ms preprocess, 1925.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1633.0ms
# Speed: 6.0ms preprocess, 1633.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1380.0ms
# Speed: 5.0ms preprocess, 1380.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 2121.0ms
# Speed: 8.0ms preprocess, 2121.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 121ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2652.0ms
# Speed: 31.0ms preprocess, 2652.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 85ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2462.0ms
# Speed: 11.0ms preprocess, 2462.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1566.0ms
# Speed: 6.0ms preprocess, 1566.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1593.0ms
# Speed: 6.0ms preprocess, 1593.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1444.0ms
# Speed: 4.0ms preprocess, 1444.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1358.0ms
# Speed: 5.0ms preprocess, 1358.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1250.0ms
# Speed: 5.0ms preprocess, 1250.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1335.0ms
# Speed: 5.0ms preprocess, 1335.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1627.0ms
# Speed: 6.0ms preprocess, 1627.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1258.0ms
# Speed: 4.0ms preprocess, 1258.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1259.0ms
# Speed: 4.0ms preprocess, 1259.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1251.0ms
# Speed: 4.0ms preprocess, 1251.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1273.0ms
# Speed: 4.0ms preprocess, 1273.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1233.0ms
# Speed: 4.0ms preprocess, 1233.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1395.0ms
# Speed: 4.0ms preprocess, 1395.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2183.0ms
# Speed: 4.0ms preprocess, 2183.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 119ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 2454.0ms
# Speed: 13.0ms preprocess, 2454.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1359.0ms
# Speed: 0.0ms preprocess, 1359.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 2234.1ms
# Speed: 0.0ms preprocess, 2234.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1654.9ms
# Speed: 0.0ms preprocess, 1654.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1986.9ms
# Speed: 0.0ms preprocess, 1986.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1511.2ms
# Speed: 11.0ms preprocess, 1511.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1489.2ms
# Speed: 0.0ms preprocess, 1489.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1523.2ms
# Speed: 17.5ms preprocess, 1523.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1535.6ms
# Speed: 15.6ms preprocess, 1535.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1558.1ms
# Speed: 0.0ms preprocess, 1558.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1642.3ms
# Speed: 8.3ms preprocess, 1642.3ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 tennis racket, 1428.0ms
# Speed: 0.0ms preprocess, 1428.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1326.6ms
# Speed: 0.0ms preprocess, 1326.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1466.4ms
# Speed: 0.0ms preprocess, 1466.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1544.8ms
# Speed: 4.0ms preprocess, 1544.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 30ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1400.8ms
# Speed: 0.0ms preprocess, 1400.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1300.4ms
# Speed: 0.0ms preprocess, 1300.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1345.1ms
# Speed: 0.0ms preprocess, 1345.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1334.1ms
# Speed: 0.0ms preprocess, 1334.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1316.3ms
# Speed: 0.0ms preprocess, 1316.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1281.8ms
# Speed: 0.0ms preprocess, 1281.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1318.8ms
# Speed: 0.0ms preprocess, 1318.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1441.3ms
# Speed: 3.6ms preprocess, 1441.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1417.2ms
# Speed: 0.0ms preprocess, 1417.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1448.0ms
# Speed: 0.0ms preprocess, 1448.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1403.6ms
# Speed: 0.0ms preprocess, 1403.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1369.8ms
# Speed: 0.0ms preprocess, 1369.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1644.3ms
# Speed: 0.0ms preprocess, 1644.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1721.6ms
# Speed: 5.0ms preprocess, 1721.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1474.1ms
# Speed: 0.0ms preprocess, 1474.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1579.5ms
# Speed: 0.0ms preprocess, 1579.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1438.4ms
# Speed: 0.0ms preprocess, 1438.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1655.0ms
# Speed: 0.0ms preprocess, 1655.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2246.6ms
# Speed: 0.0ms preprocess, 2246.6ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1551.7ms
# Speed: 0.0ms preprocess, 1551.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1663.8ms
# Speed: 0.0ms preprocess, 1663.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1511.0ms
# Speed: 6.0ms preprocess, 1511.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1486.0ms
# Speed: 5.0ms preprocess, 1486.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 clock, 1429.0ms
# Speed: 5.0ms preprocess, 1429.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1598.0ms
# Speed: 4.0ms preprocess, 1598.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1414.0ms
# Speed: 5.0ms preprocess, 1414.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1453.0ms
# Speed: 8.0ms preprocess, 1453.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1523.1ms
# Speed: 5.0ms preprocess, 1523.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1512.4ms
# Speed: 4.1ms preprocess, 1512.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1563.1ms
# Speed: 6.0ms preprocess, 1563.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1409.7ms
# Speed: 4.0ms preprocess, 1409.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1742.1ms
# Speed: 6.0ms preprocess, 1742.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1310.0ms
# Speed: 4.0ms preprocess, 1310.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1303.2ms
# Speed: 3.0ms preprocess, 1303.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1738.9ms
# Speed: 0.0ms preprocess, 1738.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1482.9ms
# Speed: 0.8ms preprocess, 1482.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2090.7ms
# Speed: 0.0ms preprocess, 2090.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 82ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 4141.7ms
# Speed: 30.9ms preprocess, 4141.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 74ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 3111.2ms
# Speed: 6.1ms preprocess, 3111.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 70ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1936.6ms
# Speed: 5.9ms preprocess, 1936.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1706.3ms
# Speed: 5.0ms preprocess, 1706.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1900.3ms
# Speed: 6.3ms preprocess, 1900.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1803.2ms
# Speed: 5.6ms preprocess, 1803.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1698.8ms
# Speed: 5.8ms preprocess, 1698.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1751.6ms
# Speed: 6.0ms preprocess, 1751.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1771.2ms
# Speed: 4.7ms preprocess, 1771.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 76ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1742.9ms
# Speed: 7.1ms preprocess, 1742.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1711.1ms
# Speed: 6.2ms preprocess, 1711.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1889.2ms
# Speed: 7.0ms preprocess, 1889.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1778.9ms
# Speed: 6.2ms preprocess, 1778.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1939.7ms
# Speed: 6.2ms preprocess, 1939.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1725.6ms
# Speed: 6.0ms preprocess, 1725.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1765.6ms
# Speed: 5.0ms preprocess, 1765.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1873.7ms
# Speed: 9.0ms preprocess, 1873.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1855.5ms
# Speed: 5.1ms preprocess, 1855.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1979.4ms
# Speed: 5.4ms preprocess, 1979.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1881.5ms
# Speed: 7.6ms preprocess, 1881.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1992.4ms
# Speed: 5.4ms preprocess, 1992.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1846.6ms
# Speed: 8.6ms preprocess, 1846.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1938.9ms
# Speed: 6.0ms preprocess, 1938.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1983.3ms
# Speed: 6.0ms preprocess, 1983.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1871.1ms
# Speed: 7.3ms preprocess, 1871.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1872.7ms
# Speed: 5.8ms preprocess, 1872.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 77ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1888.0ms
# Speed: 6.0ms preprocess, 1888.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 68ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1878.5ms
# Speed: 4.7ms preprocess, 1878.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1878.1ms
# Speed: 14.1ms preprocess, 1878.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1844.3ms
# Speed: 6.4ms preprocess, 1844.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 2022.0ms
# Speed: 5.3ms preprocess, 2022.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1944.0ms
# Speed: 7.0ms preprocess, 1944.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 74ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1855.5ms
# Speed: 6.6ms preprocess, 1855.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 2432.3ms
# Speed: 6.0ms preprocess, 2432.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2786.1ms
# Speed: 5.3ms preprocess, 2786.1ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1895.7ms
# Speed: 5.0ms preprocess, 1895.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1971.8ms
# Speed: 6.8ms preprocess, 1971.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2054.8ms
# Speed: 6.7ms preprocess, 2054.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 68ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1909.9ms
# Speed: 6.1ms preprocess, 1909.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2011.9ms
# Speed: 6.6ms preprocess, 2011.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1864.5ms
# Speed: 6.2ms preprocess, 1864.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 80ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2487.4ms
# Speed: 18.0ms preprocess, 2487.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1980.9ms
# Speed: 5.3ms preprocess, 1980.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2100.1ms
# Speed: 6.3ms preprocess, 2100.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1792.4ms
# Speed: 4.7ms preprocess, 1792.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1926.7ms
# Speed: 5.0ms preprocess, 1926.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1940.0ms
# Speed: 6.8ms preprocess, 1940.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1873.7ms
# Speed: 5.7ms preprocess, 1873.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2037.5ms
# Speed: 7.9ms preprocess, 2037.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1938.5ms
# Speed: 5.1ms preprocess, 1938.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1862.6ms
# Speed: 5.0ms preprocess, 1862.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1890.4ms
# Speed: 6.0ms preprocess, 1890.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1903.5ms
# Speed: 7.1ms preprocess, 1903.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1984.9ms
# Speed: 6.4ms preprocess, 1984.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1687.2ms
# Speed: 5.6ms preprocess, 1687.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1798.4ms
# Speed: 6.0ms preprocess, 1798.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1690.1ms
# Speed: 5.5ms preprocess, 1690.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 67ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1709.4ms
# Speed: 6.4ms preprocess, 1709.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1691.0ms
# Speed: 6.1ms preprocess, 1691.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1660.0ms
# Speed: 5.8ms preprocess, 1660.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2129.7ms
# Speed: 5.4ms preprocess, 2129.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1906.8ms
# Speed: 5.0ms preprocess, 1906.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2159.7ms
# Speed: 5.0ms preprocess, 2159.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1882.0ms
# Speed: 4.6ms preprocess, 1882.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2090.6ms
# Speed: 6.3ms preprocess, 2090.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2204.8ms
# Speed: 8.0ms preprocess, 2204.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1909.6ms
# Speed: 6.3ms preprocess, 1909.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1979.3ms
# Speed: 8.9ms preprocess, 1979.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1997.9ms
# Speed: 5.9ms preprocess, 1997.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1958.9ms
# Speed: 5.3ms preprocess, 1958.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1946.3ms
# Speed: 3.7ms preprocess, 1946.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1947.4ms
# Speed: 6.2ms preprocess, 1947.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2221.7ms
# Speed: 7.5ms preprocess, 2221.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1909.8ms
# Speed: 7.0ms preprocess, 1909.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2040.0ms
# Speed: 6.2ms preprocess, 2040.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# ...
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 3 sports balls, 1 clock, 2373.7ms
# Speed: 11.0ms preprocess, 2373.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1724.5ms
# Speed: 11.0ms preprocess, 1724.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1578.4ms
# Speed: 9.2ms preprocess, 1578.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1545.3ms
# Speed: 1.0ms preprocess, 1545.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1586.5ms
# Speed: 9.8ms preprocess, 1586.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1657.3ms
# Speed: 8.0ms preprocess, 1657.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1560.5ms
# Speed: 10.5ms preprocess, 1560.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1607.7ms
# Speed: 8.0ms preprocess, 1607.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1548.4ms
# Speed: 1.0ms preprocess, 1548.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1562.8ms
# Speed: 11.2ms preprocess, 1562.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1558.0ms
# Speed: 7.0ms preprocess, 1558.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1584.3ms
# Speed: 5.9ms preprocess, 1584.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1617.2ms
# Speed: 7.1ms preprocess, 1617.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1551.5ms
# Speed: 6.2ms preprocess, 1551.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1591.8ms
# Speed: 9.5ms preprocess, 1591.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1590.2ms
# Speed: 6.1ms preprocess, 1590.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1543.1ms
# Speed: 10.4ms preprocess, 1543.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1586.4ms
# Speed: 1.0ms preprocess, 1586.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1487.5ms
# Speed: 5.1ms preprocess, 1487.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1539.4ms
# Speed: 7.0ms preprocess, 1539.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1609.7ms
# Speed: 7.7ms preprocess, 1609.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1575.2ms
# Speed: 10.3ms preprocess, 1575.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1514.1ms
# Speed: 6.9ms preprocess, 1514.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1571.1ms
# Speed: 9.0ms preprocess, 1571.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1518.1ms
# Speed: 0.0ms preprocess, 1518.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1639.4ms
# Speed: 8.5ms preprocess, 1639.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1577.2ms
# Speed: 10.1ms preprocess, 1577.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1574.9ms
# Speed: 12.0ms preprocess, 1574.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1565.1ms
# Speed: 8.3ms preprocess, 1565.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1529.4ms
# Speed: 15.2ms preprocess, 1529.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1562.5ms
# Speed: 14.5ms preprocess, 1562.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1909.6ms
# Speed: 8.0ms preprocess, 1909.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 67ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1864.1ms
# Speed: 10.5ms preprocess, 1864.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1810.9ms
# Speed: 9.0ms preprocess, 1810.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1743.5ms
# Speed: 7.4ms preprocess, 1743.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 80ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1909.7ms
# Speed: 7.3ms preprocess, 1909.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1750.8ms
# Speed: 7.7ms preprocess, 1750.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1779.5ms
# Speed: 6.4ms preprocess, 1779.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1819.8ms
# Speed: 8.0ms preprocess, 1819.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1749.5ms
# Speed: 9.6ms preprocess, 1749.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 70ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1878.7ms
# Speed: 7.7ms preprocess, 1878.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1769.1ms
# Speed: 8.2ms preprocess, 1769.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1697.8ms
# Speed: 13.2ms preprocess, 1697.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1706.0ms
# Speed: 5.9ms preprocess, 1706.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 71ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1976.8ms
# Speed: 21.0ms preprocess, 1976.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1620.0ms
# Speed: 7.1ms preprocess, 1620.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 87ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1793.5ms
# Speed: 10.0ms preprocess, 1793.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1738.7ms
# Speed: 11.7ms preprocess, 1738.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2049.7ms
# Speed: 7.0ms preprocess, 2049.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2088.9ms
# Speed: 12.0ms preprocess, 2088.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 180ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3955.1ms
# Speed: 11.7ms preprocess, 3955.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2572.2ms
# Speed: 8.1ms preprocess, 2572.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 96ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1928.7ms
# Speed: 9.7ms preprocess, 1928.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1724.6ms
# Speed: 7.0ms preprocess, 1724.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1746.5ms
# Speed: 8.0ms preprocess, 1746.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 70ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2401.6ms
# Speed: 10.7ms preprocess, 2401.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 75ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1832.9ms
# Speed: 8.2ms preprocess, 1832.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 68ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1848.6ms
# Speed: 9.0ms preprocess, 1848.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 69ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1957.0ms
# Speed: 6.2ms preprocess, 1957.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1868.5ms
# Speed: 9.1ms preprocess, 1868.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1825.1ms
# Speed: 6.8ms preprocess, 1825.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 105ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1703.7ms
# Speed: 6.2ms preprocess, 1703.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 71ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3159.5ms
# Speed: 10.0ms preprocess, 3159.5ms inference, 26.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 76ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3712.0ms
# Speed: 30.1ms preprocess, 3712.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 89ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3162.8ms
# Speed: 71.8ms preprocess, 3162.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 88ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1881.2ms
# Speed: 14.2ms preprocess, 1881.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 75ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1740.9ms
# Speed: 19.4ms preprocess, 1740.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1743.1ms
# Speed: 8.5ms preprocess, 1743.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1656.2ms
# Speed: 7.3ms preprocess, 1656.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1635.6ms
# Speed: 6.4ms preprocess, 1635.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1597.4ms
# Speed: 9.0ms preprocess, 1597.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1728.4ms
# Speed: 13.8ms preprocess, 1728.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1632.1ms
# Speed: 13.7ms preprocess, 1632.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1618.0ms
# Speed: 6.7ms preprocess, 1618.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
# [[148, 122, 139, 120, 113, 124], [146, 157, 144, 122, 114, 122], [149, 146, 145, 119, 116, 117]]
# PDF created for 1
# PDF created for 2
# PDF created for 3
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\1\1.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\2\2.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\3\3.pdf
# PDF creation complete.
